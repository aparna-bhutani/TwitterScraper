# %%
import tweepy
import pandas as pd
import time

# %% [markdown]
# ### Twitter Credentials (Updating the twitter credentials in the twitter_credentials.csv file and loading it here)

# %%
credentials_df = pd.read_csv('twitter_credentials.csv',header=None,names=['Name','Key'])
credentials_df
# Out:
#               Name                                                Key
# 0     consumer_key                          CvbMui2D4MuIK5dxzT0mR03s8
# 1  consumer_secret  YkrRUAfCCi9h0mDzThuzNb5d7CSDjQwb4SwDzQWaErVopt...
# 2     access_token  895342019668619264-lQ9NRAL8URrYfIpRSS1fbVMcUpk...
# 3    access_secret      naWmOWyX6XDN8f1khdmh2KodtOIr6DOmEjqipyQyetUgV

# %%
consumer_key = credentials_df.loc[credentials_df['Name']=='consumer_key','Key'].iloc[0]
consumer_secret = credentials_df.loc[credentials_df['Name']=='consumer_secret','Key'].iloc[0]
access_token = credentials_df.loc[credentials_df['Name']=='access_token','Key'].iloc[0]
access_token_secret = credentials_df.loc[credentials_df['Name']=='access_secret','Key'].iloc[0]

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
tweet_url = pd.read_csv("Trump/UrlFiles/trump_tweets_jan_urls.txt", index_col= None, header = None, names = ["links"])
tweet_url.head()
# Out:
#                                                links
# 0  https://twitter.com/BobbyHardcastle/status/121...
# 1  https://twitter.com/TLinsdau/status/1216872491...
# 2  https://twitter.com/Lyngvie1/status/1216872483...
# 3  https://twitter.com/mortonie/status/1216872480...
# 4  https://twitter.com/HolleSharon/status/1216872...

# %%
af = lambda x: x["links"].split("/")[-1]
tweet_url['id'] = tweet_url.apply(af, axis=1)
tweet_url.head()
# Out:
#                                                links                   id
# 0  https://twitter.com/BobbyHardcastle/status/121...  1216872493815861248
# 1  https://twitter.com/TLinsdau/status/1216872491...  1216872491940925440
# 2  https://twitter.com/Lyngvie1/status/1216872483...  1216872483866980354
# 3  https://twitter.com/mortonie/status/1216872480...  1216872480146477056
# 4  https://twitter.com/HolleSharon/status/1216872...  1216872476141129731

# %%
ids = tweet_url['id'].tolist()

# %%
total_count = len(ids)
chunks = (total_count - 1) // 50 + 1

# %%
total_count
# Out:
# 294537

# %%
def fetch_tw(ids):
    list_of_tw_status = api.statuses_lookup(ids, tweet_mode= "extended")
    empty_data = pd.DataFrame()
    for status in list_of_tw_status:
            tweet_elem = {"tweet_id": status.id,
                     "screen_name": status.user.screen_name,
                     "tweet":status.full_text,
                     "date":status.created_at,
                     "coordinates":status.coordinates,
                     "location": status.user.location,
                     "place": status.place
                        }
            empty_data = empty_data.append(tweet_elem, ignore_index = True)
    empty_data.to_csv("trump_tweets_jan1.csv", mode="a")

# %%
for i in range(chunks):
        batch = ids[i*50:(i+1)*50]
        result = fetch_tw(batch)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 49] Can't assign requested address
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7fa1a7038090>: Failed to establish a new connection: [Errno 49] Can't assign requested address
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /opt/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=1214813374506123265%2C1214813351995461634%2C1214813340234604544%2C1214813339047600129%2C1214813333477560320%2C1214813321242775559%2C1214813320458440710%2C1214813286887239682%2C1214813263961174016%2C1214813243904086018%2C1214813235188252672%2C1214813216913707010%2C1214813202560770048%2C1214813196177072130%2C1214813168796622848%2C1214813137989451776%2C1214813082226171904%2C1214813046217953280%2C1214813010046398464%2C1214812988215058434%2C1214812967075758080%2C1214812948721545216%2C1214812946502537216%2C1214812931394822145%2C1214812919923232769%2C1214812916010094592%2C1214812829238398976%2C1214812805234380800%2C1214812780576071680%2C1214812742001053696%2C1214812738872074240%2C1214812621981016064%2C1214812593203924992%2C1214812550254223360%2C1214812535100182528%2C1214812533657391105%2C1214812533564960768%2C1214812507610726401%2C1214812498047766528%2C1214812490716078081%2C1214812488476184576%2C1214812487377391616%2C1214812484181340161%2C1214812432410935297%2C1214812394091941888%2C1214812386340802563%2C1214812380602851329%2C1214812379395100672%2C1214812344016084992%2C1214812332691509248&tweet_mode=extended (Caused by NewConnectionError("<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa1a7038090>: Failed to establish a new connection: [Errno 49] Can't assign requested address"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=1214813374506123265%2C1214813351995461634%2C1214813340234604544%2C1214813339047600129%2C1214813333477560320%2C1214813321242775559%2C1214813320458440710%2C1214813286887239682%2C1214813263961174016%2C1214813243904086018%2C1214813235188252672%2C1214813216913707010%2C1214813202560770048%2C1214813196177072130%2C1214813168796622848%2C1214813137989451776%2C1214813082226171904%2C1214813046217953280%2C1214813010046398464%2C1214812988215058434%2C1214812967075758080%2C1214812948721545216%2C1214812946502537216%2C1214812931394822145%2C1214812919923232769%2C1214812916010094592%2C1214812829238398976%2C1214812805234380800%2C1214812780576071680%2C1214812742001053696%2C1214812738872074240%2C1214812621981016064%2C1214812593203924992%2C1214812550254223360%2C1214812535100182528%2C1214812533657391105%2C1214812533564960768%2C1214812507610726401%2C1214812498047766528%2C1214812490716078081%2C1214812488476184576%2C1214812487377391616%2C1214812484181340161%2C1214812432410935297%2C1214812394091941888%2C1214812386340802563%2C1214812380602851329%2C1214812379395100672%2C1214812344016084992%2C1214812332691509248&tweet_mode=extended (Caused by NewConnectionError("<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa1a7038090>: Failed to establish a new connection: [Errno 49] Can't assign requested address"))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-60-7eef80f31206> in <module>
#       1 for i in range(chunks):
#       2         batch = ids[i*50:(i+1)*50]
# ----> 3         result = fetch_tw(batch)
#
# <ipython-input-59-c048ac0ce2f9> in fetch_tw(ids)
#       1 def fetch_tw(ids):
# ----> 2     list_of_tw_status = api.statuses_lookup(ids, tweet_mode= "extended")
#       3     empty_data = pd.DataFrame()
#       4     for status in list_of_tw_status:
#       5             tweet_elem = {"tweet_id": status.id,
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/api.py in statuses_lookup(self, id_, include_entities, trim_user, map_, tweet_mode)
#      95                         trim_user=None, map_=None, tweet_mode=None):
#      96         return self._statuses_lookup(list_to_csv(id_), include_entities,
# ---> 97                                      trim_user, map_, tweet_mode)
#      98
#      99     @property
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
# --> 191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     192
#     193                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# /opt/anaconda3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# /opt/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/statuses/lookup.json?id=1214813374506123265%2C1214813351995461634%2C1214813340234604544%2C1214813339047600129%2C1214813333477560320%2C1214813321242775559%2C1214813320458440710%2C1214813286887239682%2C1214813263961174016%2C1214813243904086018%2C1214813235188252672%2C1214813216913707010%2C1214813202560770048%2C1214813196177072130%2C1214813168796622848%2C1214813137989451776%2C1214813082226171904%2C1214813046217953280%2C1214813010046398464%2C1214812988215058434%2C1214812967075758080%2C1214812948721545216%2C1214812946502537216%2C1214812931394822145%2C1214812919923232769%2C1214812916010094592%2C1214812829238398976%2C1214812805234380800%2C1214812780576071680%2C1214812742001053696%2C1214812738872074240%2C1214812621981016064%2C1214812593203924992%2C1214812550254223360%2C1214812535100182528%2C1214812533657391105%2C1214812533564960768%2C1214812507610726401%2C1214812498047766528%2C1214812490716078081%2C1214812488476184576%2C1214812487377391616%2C1214812484181340161%2C1214812432410935297%2C1214812394091941888%2C1214812386340802563%2C1214812380602851329%2C1214812379395100672%2C1214812344016084992%2C1214812332691509248&tweet_mode=extended (Caused by NewConnectionError("<urllib3.connection.VerifiedHTTPSConnection object at 0x7fa1a7038090>: Failed to establish a new connection: [Errno 49] Can't assign requested address"))

# %% [markdown]
# ## Sentimental Analysis

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import matplotlib
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Trump/Tweets/trump_tweets_feb.csv',lineterminator='\n')
df1
# Out:
#         Unnamed: 0                 date     screen_name  \
# 0              0.0  2020-02-13 23:59:40  bitcoinconnect
# 1              1.0  2020-02-13 23:57:35      Suzzzzeee1
# 2              2.0  2020-02-13 23:56:49    juicejuice64
# 3              3.0  2020-02-13 23:54:05     puppygrammy
# 4              4.0  2020-02-13 23:56:18  KhalilEJahshan
# ...            ...                  ...             ...
# 284498        45.0  2020-01-20 00:32:52     MrGeorgeCee
# 284499        46.0  2020-01-20 00:28:00   Shadowmoons77
# 284500        47.0  2020-01-20 00:27:15  TrumpsEmotions
# 284501        48.0  2020-01-20 00:25:48     haqsmusings
# 284502        49.0  2020-01-20 00:29:20        mkraft77
#
#                                                     tweet  \
# 0       Coronavirus: What it does to the body SURVIVE ...
# 1       Conservatives/NeverTrumpers that would vote fo...
# 2       @marcushjohnson @battletested5 Oh so now they'...
# 3       “My job is to make decisions based on what I t...
# 4       I’ve known Adel al-Jubeir for many years: the ...
# ...                                                   ...
# 284498  Let's stop revising #history: #Reagan didn't w...
# 284499  @GmanisQ @rosieogrady53 @DavidPriess I agree a...
# 284500  Trump is currently making good deals, the best...
# 284501  Senior #US Diplomat Alice Wells in #Pakistan A...
# 284502  @MarkSKrikorian \n\n"President Trump needs to ...
#
#                       tweet_id
# 0       1.2281064951051264e+18
# 1       1.2281059705780675e+18
# 2       1.2281057788186173e+18
# 3       1.2281050929828086e+18
# 4        1.228105647381762e+18
# ...                        ...
# 284498  1.2190551548524995e+18
# 284499  1.2190539301366374e+18
# 284500  1.2190537414012396e+18
# 284501   1.219053374970065e+18
# 284502  1.2190542665365955e+18
#
# [284503 rows x 5 columns]

# %% [markdown]
# ### Data Processing

# %%
Corpus = df1.copy()
display(Corpus.head())
print('I collected {} tweets.'.format(len(Corpus)))
# Out:
#    Unnamed: 0                 date      screen_name  \
# 0         0.0  2020-03-13 23:58:00        Imagen_Mx
# 1         1.0  2020-03-13 23:58:46    howardfineman
# 2         2.0  2020-03-13 23:58:13       MH88490684
# 3         3.0  2020-03-13 23:59:29       Serbie_KiM
# 4         4.0  2020-03-13 23:59:53  chngin_the_wrld
#
#                                                tweet                tweet_id
# 0  #Trump anuncia suspensión a cruceros desde pue...  1.2386153238484337e+18
# 1  Contrary to #Trump’s claim, #Google is not bui...  1.2386155174029885e+18
# 2  Where there’s smoke there’s fire, ah la Gillum...  1.2386153797627003e+18
# 3  #Bolsonaro est infecté par le #coronavirus... ...  1.2386156973720863e+18
# 4  Some good news on #SARS_COV_2 #COVID19 relief ...   1.238615798509269e+18
# I collected 127332 tweets.

# %%
#converting all data to lowercase
df1['lowercase']=df1['tweet'].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
df1
# Out:
#         Unnamed: 0                 date      screen_name  \
# 0              0.0  2020-03-13 23:58:00        Imagen_Mx
# 1              1.0  2020-03-13 23:58:46    howardfineman
# 2              2.0  2020-03-13 23:58:13       MH88490684
# 3              3.0  2020-03-13 23:59:29       Serbie_KiM
# 4              4.0  2020-03-13 23:59:53  chngin_the_wrld
# ...            ...                  ...              ...
# 127327        45.0  2020-03-07 20:36:42       PegoBlanco
# 127328        46.0  2020-03-07 20:39:52   JSSciencefocus
# 127329        47.0  2020-03-07 20:39:47           jbveen
# 127330        48.0  2020-03-07 20:36:58      NicoleNonya
# 127331        49.0  2020-03-07 20:39:57          mtnpoet
#
#                                                     tweet  \
# 0       #Trump anuncia suspensión a cruceros desde pue...
# 1       Contrary to #Trump’s claim, #Google is not bui...
# 2       Where there’s smoke there’s fire, ah la Gillum...
# 3       #Bolsonaro est infecté par le #coronavirus... ...
# 4       Some good news on #SARS_COV_2 #COVID19 relief ...
# ...                                                   ...
# 127327  @DarioMedinaM Pinocho avergonzado de #Trump al...
# 127328  @lastuto9 @matthewherper Here is one quote, it...
# 127329  The government’s scientists and leading health...
# 127330  @CapaTosta122 #Berniebros have funded  #notmeu...
# 127331  @rwmercer @washingtonpost I've listened to wha...
#
#                       tweet_id  \
# 0       1.2386153238484337e+18
# 1       1.2386155174029885e+18
# 2       1.2386153797627003e+18
# 3       1.2386156973720863e+18
# 4        1.238615798509269e+18
# ...                        ...
# 127327  1.2363903371968102e+18
# 127328  1.2363911346596209e+18
# 127329  1.2363911165276856e+18
# 127330  1.2363904076695142e+18
# 127331  1.2363911553459282e+18
#
#                                                 lowercase
# 0       #trump anuncia suspensión a cruceros desde pue...
# 1       contrary to #trump’s claim, #google is not bui...
# 2       where there’s smoke there’s fire, ah la gillum...
# 3       #bolsonaro est infecté par le #coronavirus... ...
# 4       some good news on #sars_cov_2 #covid19 relief ...
# ...                                                   ...
# 127327  @dariomedinam pinocho avergonzado de #trump al...
# 127328  @lastuto9 @matthewherper here is one quote, it...
# 127329  the government’s scientists and leading health...
# 127330  @capatosta122 #berniebros have funded #notmeus...
# 127331  @rwmercer @washingtonpost i've listened to wha...
#
# [127332 rows x 6 columns]

# %%
df1['punctuation']=df1['lowercase'].str.replace('[^\w\s]','')
df1
# Out:
#         Unnamed: 0                 date      screen_name  \
# 0              0.0  2020-03-13 23:58:00        Imagen_Mx
# 1              1.0  2020-03-13 23:58:46    howardfineman
# 2              2.0  2020-03-13 23:58:13       MH88490684
# 3              3.0  2020-03-13 23:59:29       Serbie_KiM
# 4              4.0  2020-03-13 23:59:53  chngin_the_wrld
# ...            ...                  ...              ...
# 127327        45.0  2020-03-07 20:36:42       PegoBlanco
# 127328        46.0  2020-03-07 20:39:52   JSSciencefocus
# 127329        47.0  2020-03-07 20:39:47           jbveen
# 127330        48.0  2020-03-07 20:36:58      NicoleNonya
# 127331        49.0  2020-03-07 20:39:57          mtnpoet
#
#                                                     tweet  \
# 0       #Trump anuncia suspensión a cruceros desde pue...
# 1       Contrary to #Trump’s claim, #Google is not bui...
# 2       Where there’s smoke there’s fire, ah la Gillum...
# 3       #Bolsonaro est infecté par le #coronavirus... ...
# 4       Some good news on #SARS_COV_2 #COVID19 relief ...
# ...                                                   ...
# 127327  @DarioMedinaM Pinocho avergonzado de #Trump al...
# 127328  @lastuto9 @matthewherper Here is one quote, it...
# 127329  The government’s scientists and leading health...
# 127330  @CapaTosta122 #Berniebros have funded  #notmeu...
# 127331  @rwmercer @washingtonpost I've listened to wha...
#
#                       tweet_id  \
# 0       1.2386153238484337e+18
# 1       1.2386155174029885e+18
# 2       1.2386153797627003e+18
# 3       1.2386156973720863e+18
# 4        1.238615798509269e+18
# ...                        ...
# 127327  1.2363903371968102e+18
# 127328  1.2363911346596209e+18
# 127329  1.2363911165276856e+18
# 127330  1.2363904076695142e+18
# 127331  1.2363911553459282e+18
#
#                                                 lowercase  \
# 0       #trump anuncia suspensión a cruceros desde pue...
# 1       contrary to #trump’s claim, #google is not bui...
# 2       where there’s smoke there’s fire, ah la gillum...
# 3       #bolsonaro est infecté par le #coronavirus... ...
# 4       some good news on #sars_cov_2 #covid19 relief ...
# ...                                                   ...
# 127327  @dariomedinam pinocho avergonzado de #trump al...
# 127328  @lastuto9 @matthewherper here is one quote, it...
# 127329  the government’s scientists and leading health...
# 127330  @capatosta122 #berniebros have funded #notmeus...
# 127331  @rwmercer @washingtonpost i've listened to wha...
#
#                                               punctuation
# 0       trump anuncia suspensión a cruceros desde puer...
# 1       contrary to trumps claim google is not buildin...
# 2       where theres smoke theres fire ah la gillums t...
# 3       bolsonaro est infecté par le coronavirus tous ...
# 4       some good news on sars_cov_2 covid19 relief in...
# ...                                                   ...
# 127327  dariomedinam pinocho avergonzado de trump alia...
# 127328  lastuto9 matthewherper here is one quote it il...
# 127329  the governments scientists and leading health ...
# 127330  capatosta122 berniebros have funded notmeus to...
# 127331  rwmercer washingtonpost ive listened to what t...
#
# [127332 rows x 7 columns]

# %%
stop_words=stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
df1['stopwords']=df1['punctuation'].apply(lambda x: " ".join(word for word in x.split()if word not in stop_words))

# %%
df1.head()
# Out:
#    Unnamed: 0                 date      screen_name  \
# 0         0.0  2020-03-13 23:58:00        Imagen_Mx
# 1         1.0  2020-03-13 23:58:46    howardfineman
# 2         2.0  2020-03-13 23:58:13       MH88490684
# 3         3.0  2020-03-13 23:59:29       Serbie_KiM
# 4         4.0  2020-03-13 23:59:53  chngin_the_wrld
#
#                                                tweet                tweet_id  \
# 0  #Trump anuncia suspensión a cruceros desde pue...  1.2386153238484337e+18
# 1  Contrary to #Trump’s claim, #Google is not bui...  1.2386155174029885e+18
# 2  Where there’s smoke there’s fire, ah la Gillum...  1.2386153797627003e+18
# 3  #Bolsonaro est infecté par le #coronavirus... ...  1.2386156973720863e+18
# 4  Some good news on #SARS_COV_2 #COVID19 relief ...   1.238615798509269e+18
#
#                                            lowercase  \
# 0  #trump anuncia suspensión a cruceros desde pue...
# 1  contrary to #trump’s claim, #google is not bui...
# 2  where there’s smoke there’s fire, ah la gillum...
# 3  #bolsonaro est infecté par le #coronavirus... ...
# 4  some good news on #sars_cov_2 #covid19 relief ...
#
#                                          punctuation  \
# 0  trump anuncia suspensión a cruceros desde puer...
# 1  contrary to trumps claim google is not buildin...
# 2  where theres smoke theres fire ah la gillums t...
# 3  bolsonaro est infecté par le coronavirus tous ...
# 4  some good news on sars_cov_2 covid19 relief in...
#
#                                            stopwords
# 0  trump anuncia suspensión cruceros desde puerto...
# 1  contrary trumps claim google building nationwi...
# 2  theres smoke theres fire ah la gillums travel ...
# 3  bolsonaro est infecté par le coronavirus tous ...
# 4  good news sars_cov_2 covid19 relief us long tr...

# %% [markdown]
# ### Lemmatization

# %%
#import Textblob
from textblob import TextBlob 
from textblob import Word

# %%
df1['lemmatize']=df1['stopwords'].apply(lambda x:" ".join(Word(word).lemmatize() for word in x.split()))

# %%
df1['polarity']=df1['lemmatize'].apply(lambda x: TextBlob(x).sentiment[0])## just got polarity

# %%
df1['subjectivity']=df1['lemmatize'].apply(lambda x: TextBlob(x).sentiment[1])## just got polarity

# %%
df1.head()
# Out:
#    Unnamed: 0                 date      screen_name  \
# 0         0.0  2020-03-13 23:58:00        Imagen_Mx
# 1         1.0  2020-03-13 23:58:46    howardfineman
# 2         2.0  2020-03-13 23:58:13       MH88490684
# 3         3.0  2020-03-13 23:59:29       Serbie_KiM
# 4         4.0  2020-03-13 23:59:53  chngin_the_wrld
#
#                                                tweet                tweet_id  \
# 0  #Trump anuncia suspensión a cruceros desde pue...  1.2386153238484337e+18
# 1  Contrary to #Trump’s claim, #Google is not bui...  1.2386155174029885e+18
# 2  Where there’s smoke there’s fire, ah la Gillum...  1.2386153797627003e+18
# 3  #Bolsonaro est infecté par le #coronavirus... ...  1.2386156973720863e+18
# 4  Some good news on #SARS_COV_2 #COVID19 relief ...   1.238615798509269e+18
#
#                                            lowercase  \
# 0  #trump anuncia suspensión a cruceros desde pue...
# 1  contrary to #trump’s claim, #google is not bui...
# 2  where there’s smoke there’s fire, ah la gillum...
# 3  #bolsonaro est infecté par le #coronavirus... ...
# 4  some good news on #sars_cov_2 #covid19 relief ...
#
#                                          punctuation  \
# 0  trump anuncia suspensión a cruceros desde puer...
# 1  contrary to trumps claim google is not buildin...
# 2  where theres smoke theres fire ah la gillums t...
# 3  bolsonaro est infecté par le coronavirus tous ...
# 4  some good news on sars_cov_2 covid19 relief in...
#
#                                            stopwords  \
# 0  trump anuncia suspensión cruceros desde puerto...
# 1  contrary trumps claim google building nationwi...
# 2  theres smoke theres fire ah la gillums travel ...
# 3  bolsonaro est infecté par le coronavirus tous ...
# 4  good news sars_cov_2 covid19 relief us long tr...
#
#                                            lemmatize  polarity  subjectivity
# 0  trump anuncia suspensión cruceros desde puerto...     0.000           0.0
# 1  contrary trump claim google building nationwid...     0.000           0.0
# 2  there smoke there fire ah la gillums travel sh...     0.000           0.0
# 3  bolsonaro est infecté par le coronavirus tous ...     0.000           0.0
# 4  good news sars_cov_2 covid19 relief u long tru...     0.325           0.5

# %% [markdown]
# ### Tweets with sentiments (-1 = negative, +1 = posiitive, 0 = neutral)

# %%
num_bins = 10
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(df1.polarity, num_bins, facecolor='green', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.title('Histogram of Tweets sentiments (-1 = negative, +1 = posiitive, 0 = neutral)')
plt.show();
