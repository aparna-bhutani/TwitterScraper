# %%
import tweepy
import pandas as pd
import time

# %% [markdown]
# ### Twitter Credentials (Updating the twitter credentials in the twitter_credentials.csv file and loading it here)

# %%
credentials_df = pd.read_csv('twitter_credentials.csv',header=None,names=['Name','Key'])
credentials_df
# Out:
#               Name                                                Key
# 0     consumer_key                          CvbMui2D4MuIK5dxzT0mR03s8
# 1  consumer_secret  YkrRUAfCCi9h0mDzThuzNb5d7CSDjQwb4SwDzQWaErVopt...
# 2     access_token  895342019668619264-lQ9NRAL8URrYfIpRSS1fbVMcUpk...
# 3    access_secret      naWmOWyX6XDN8f1khdmh2KodtOIr6DOmEjqipyQyetUgV

# %%
consumer_key = credentials_df.loc[credentials_df['Name']=='consumer_key','Key'].iloc[0]
consumer_secret = credentials_df.loc[credentials_df['Name']=='consumer_secret','Key'].iloc[0]
access_token = credentials_df.loc[credentials_df['Name']=='access_token','Key'].iloc[0]
access_token_secret = credentials_df.loc[credentials_df['Name']=='access_secret','Key'].iloc[0]

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret) 
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
tweet_url = pd.read_csv("/Trumppres2_tweets.txt", index_col= None, header = None, names = ["links"])
tweet_url.head()
# Out:
#                                                links
# 0  https://twitter.com/AndruM25/status/1311093387...
# 1  https://twitter.com/awesomeprint202/status/131...
# 2  https://twitter.com/SimplySam47/status/1311093...
# 3  https://twitter.com/youngkushdro/status/131109...
# 4  https://twitter.com/4starsoutof501/status/1311...

# %%
af = lambda x: x["links"].split("/")[-1]
tweet_url['id'] = tweet_url.apply(af, axis=1)

# %%
tweet_url.head()
# Out:
#                                                links                   id
# 0  https://twitter.com/AndruM25/status/1311093387...  1311093387718778882
# 1  https://twitter.com/awesomeprint202/status/131...  1313067184805957637
# 2  https://twitter.com/SimplySam47/status/1311093...  1311093380781412354
# 3  https://twitter.com/youngkushdro/status/131109...  1311093376670982150
# 4  https://twitter.com/4starsoutof501/status/1311...  1311093351832260608

# %%
ids = tweet_url['id'].tolist()

# %%
total_count = len(ids)
chunks = (total_count - 1) // 50 + 1

# %%
total_count
# Out:
# 6475

# %%
def fetch_tw(ids):
    list_of_tw_status = api.statuses_lookup(ids, tweet_mode= "extended")
    empty_data = pd.DataFrame()
    for status in list_of_tw_status:
            tweet_elem = {"tweet_id": status.id,
                     "screen_name": status.user.screen_name,
                     "tweet":status.full_text,
                     "date":status.created_at}
            empty_data = empty_data.append(tweet_elem, ignore_index = True)
    empty_data.to_csv("president_tweets.csv", mode="a")

# %%
for i in range(chunks):
        batch = ids[i*50:(i+1)*50]
        result = fetch_tw(batch)

# %% [markdown]
# ## Sentimental Analysis

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import matplotlib
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('president_tweets.csv')
df1
# Out:
#       Unnamed: 0                 date      screen_name  \
# 0            0.0  2020-09-29 23:59:39    JonDonsSweety
# 1            1.0  2020-09-29 23:59:20           Bixcut
# 2            2.0  2020-09-29 23:59:54     youngkushdro
# 3            3.0  2020-09-29 23:59:45        Divababie
# 4            4.0  2020-09-29 23:59:21   coachgratitude
# ...          ...                  ...              ...
# 6598        20.0  2020-09-28 00:37:07        liamiller
# 6599        21.0  2020-09-28 00:27:32     Hwy2Hysteria
# 6600        22.0  2020-09-28 00:21:28       FitzBishop
# 6601        23.0  2020-09-28 00:01:45   politicarebear
# 6602        24.0  2020-09-28 00:35:26  ChillWitCharles
#
#                                                   tweet  \
# 0     #BidenHarris2020 #DumpTrump #DumpTrump2020 #Pr...
# 1     It’s debate night, so I’ve got my earpiece and...
# 2                 Go joe!!! #PresidentialDebate #debate
# 3     Getting ready for the #debate   I have rum, te...
# 4        Who TF is still undecided? #PresidentialDebate
# ...                                                 ...
# 6598  What if there’s fisticuffs at Tuesday’s debate...
# 6599  @MTC_CO @pbump The challenge for #ChrisWallace...
# 6600  The #PresidentialDebate ought to be quite amus...
# 6601  who are u voting for? #biden2020 #trump2020 #P...
# 6602  Trump and Biden will debate on Tuesday. Jo Jor...
#
#                     tweet_id
# 0     1.3110933115418583e+18
# 1      1.311093234265809e+18
# 2     1.3110933766709821e+18
# 3     1.3110933405118874e+18
# 4     1.3110932385232036e+18
# ...                      ...
# 6598  1.3103779679613747e+18
# 6599  1.3103755540639703e+18
# 6600   1.310374028851454e+18
# 6601   1.310369066230657e+18
# 6602  1.3103775447268434e+18
#
# [6603 rows x 5 columns]

# %% [markdown]
# ### Data Processing

# %%
Corpus = df1.copy()
display(Corpus.head())
print('I collected {} tweets.'.format(len(Corpus)))
# Out:
#    Unnamed: 0                 date     screen_name  \
# 0         0.0  2020-09-29 23:59:39   JonDonsSweety
# 1         1.0  2020-09-29 23:59:20          Bixcut
# 2         2.0  2020-09-29 23:59:54    youngkushdro
# 3         3.0  2020-09-29 23:59:45       Divababie
# 4         4.0  2020-09-29 23:59:21  coachgratitude
#
#                                                tweet                tweet_id
# 0  #BidenHarris2020 #DumpTrump #DumpTrump2020 #Pr...  1.3110933115418583e+18
# 1  It’s debate night, so I’ve got my earpiece and...   1.311093234265809e+18
# 2              Go joe!!! #PresidentialDebate #debate  1.3110933766709821e+18
# 3  Getting ready for the #debate   I have rum, te...  1.3110933405118874e+18
# 4     Who TF is still undecided? #PresidentialDebate  1.3110932385232036e+18
# I collected 6603 tweets.

# %%
#converting all data to lowercase
df1['lowercase']=df1['tweet'].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
df1
# Out:
#       Unnamed: 0                 date      screen_name  \
# 0            0.0  2020-09-29 23:59:39    JonDonsSweety
# 1            1.0  2020-09-29 23:59:20           Bixcut
# 2            2.0  2020-09-29 23:59:54     youngkushdro
# 3            3.0  2020-09-29 23:59:45        Divababie
# 4            4.0  2020-09-29 23:59:21   coachgratitude
# ...          ...                  ...              ...
# 6598        20.0  2020-09-28 00:37:07        liamiller
# 6599        21.0  2020-09-28 00:27:32     Hwy2Hysteria
# 6600        22.0  2020-09-28 00:21:28       FitzBishop
# 6601        23.0  2020-09-28 00:01:45   politicarebear
# 6602        24.0  2020-09-28 00:35:26  ChillWitCharles
#
#                                                   tweet  \
# 0     #BidenHarris2020 #DumpTrump #DumpTrump2020 #Pr...
# 1     It’s debate night, so I’ve got my earpiece and...
# 2                 Go joe!!! #PresidentialDebate #debate
# 3     Getting ready for the #debate   I have rum, te...
# 4        Who TF is still undecided? #PresidentialDebate
# ...                                                 ...
# 6598  What if there’s fisticuffs at Tuesday’s debate...
# 6599  @MTC_CO @pbump The challenge for #ChrisWallace...
# 6600  The #PresidentialDebate ought to be quite amus...
# 6601  who are u voting for? #biden2020 #trump2020 #P...
# 6602  Trump and Biden will debate on Tuesday. Jo Jor...
#
#                     tweet_id  \
# 0     1.3110933115418583e+18
# 1      1.311093234265809e+18
# 2     1.3110933766709821e+18
# 3     1.3110933405118874e+18
# 4     1.3110932385232036e+18
# ...                      ...
# 6598  1.3103779679613747e+18
# 6599  1.3103755540639703e+18
# 6600   1.310374028851454e+18
# 6601   1.310369066230657e+18
# 6602  1.3103775447268434e+18
#
#                                               lowercase
# 0     #bidenharris2020 #dumptrump #dumptrump2020 #pr...
# 1     it’s debate night, so i’ve got my earpiece and...
# 2                 go joe!!! #presidentialdebate #debate
# 3     getting ready for the #debate i have rum, tequ...
# 4        who tf is still undecided? #presidentialdebate
# ...                                                 ...
# 6598  what if there’s fisticuffs at tuesday’s debate...
# 6599  @mtc_co @pbump the challenge for #chriswallace...
# 6600  the #presidentialdebate ought to be quite amus...
# 6601  who are u voting for? #biden2020 #trump2020 #p...
# 6602  trump and biden will debate on tuesday. jo jor...
#
# [6603 rows x 6 columns]

# %%
df1['punctuation']=df1['lowercase'].str.replace('[^\w\s]','')
df1
# Out:
#       Unnamed: 0                 date      screen_name  \
# 0            0.0  2020-09-29 23:59:39    JonDonsSweety
# 1            1.0  2020-09-29 23:59:20           Bixcut
# 2            2.0  2020-09-29 23:59:54     youngkushdro
# 3            3.0  2020-09-29 23:59:45        Divababie
# 4            4.0  2020-09-29 23:59:21   coachgratitude
# ...          ...                  ...              ...
# 6598        20.0  2020-09-28 00:37:07        liamiller
# 6599        21.0  2020-09-28 00:27:32     Hwy2Hysteria
# 6600        22.0  2020-09-28 00:21:28       FitzBishop
# 6601        23.0  2020-09-28 00:01:45   politicarebear
# 6602        24.0  2020-09-28 00:35:26  ChillWitCharles
#
#                                                   tweet  \
# 0     #BidenHarris2020 #DumpTrump #DumpTrump2020 #Pr...
# 1     It’s debate night, so I’ve got my earpiece and...
# 2                 Go joe!!! #PresidentialDebate #debate
# 3     Getting ready for the #debate   I have rum, te...
# 4        Who TF is still undecided? #PresidentialDebate
# ...                                                 ...
# 6598  What if there’s fisticuffs at Tuesday’s debate...
# 6599  @MTC_CO @pbump The challenge for #ChrisWallace...
# 6600  The #PresidentialDebate ought to be quite amus...
# 6601  who are u voting for? #biden2020 #trump2020 #P...
# 6602  Trump and Biden will debate on Tuesday. Jo Jor...
#
#                     tweet_id  \
# 0     1.3110933115418583e+18
# 1      1.311093234265809e+18
# 2     1.3110933766709821e+18
# 3     1.3110933405118874e+18
# 4     1.3110932385232036e+18
# ...                      ...
# 6598  1.3103779679613747e+18
# 6599  1.3103755540639703e+18
# 6600   1.310374028851454e+18
# 6601   1.310369066230657e+18
# 6602  1.3103775447268434e+18
#
#                                               lowercase  \
# 0     #bidenharris2020 #dumptrump #dumptrump2020 #pr...
# 1     it’s debate night, so i’ve got my earpiece and...
# 2                 go joe!!! #presidentialdebate #debate
# 3     getting ready for the #debate i have rum, tequ...
# 4        who tf is still undecided? #presidentialdebate
# ...                                                 ...
# 6598  what if there’s fisticuffs at tuesday’s debate...
# 6599  @mtc_co @pbump the challenge for #chriswallace...
# 6600  the #presidentialdebate ought to be quite amus...
# 6601  who are u voting for? #biden2020 #trump2020 #p...
# 6602  trump and biden will debate on tuesday. jo jor...
#
#                                             punctuation
# 0     bidenharris2020 dumptrump dumptrump2020 presid...
# 1     its debate night so ive got my earpiece and pe...
# 2                      go joe presidentialdebate debate
# 3     getting ready for the debate i have rum tequil...
# 4          who tf is still undecided presidentialdebate
# ...                                                 ...
# 6598  what if theres fisticuffs at tuesdays debate p...
# 6599  mtc_co pbump the challenge for chriswallace an...
# 6600  the presidentialdebate ought to be quite amusi...
# 6601  who are u voting for biden2020 trump2020 presi...
# 6602  trump and biden will debate on tuesday jo jorg...
#
# [6603 rows x 7 columns]

# %%
stop_words=stopwords.words('english')
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
df1['stopwords']=df1['punctuation'].apply(lambda x: " ".join(word for word in x.split()if word not in stop_words))

# %%
df1.head()
# Out:
#    Unnamed: 0                 date     screen_name  \
# 0         0.0  2020-09-29 23:59:39   JonDonsSweety
# 1         1.0  2020-09-29 23:59:20          Bixcut
# 2         2.0  2020-09-29 23:59:54    youngkushdro
# 3         3.0  2020-09-29 23:59:45       Divababie
# 4         4.0  2020-09-29 23:59:21  coachgratitude
#
#                                                tweet                tweet_id  \
# 0  #BidenHarris2020 #DumpTrump #DumpTrump2020 #Pr...  1.3110933115418583e+18
# 1  It’s debate night, so I’ve got my earpiece and...   1.311093234265809e+18
# 2              Go joe!!! #PresidentialDebate #debate  1.3110933766709821e+18
# 3  Getting ready for the #debate   I have rum, te...  1.3110933405118874e+18
# 4     Who TF is still undecided? #PresidentialDebate  1.3110932385232036e+18
#
#                                            lowercase  \
# 0  #bidenharris2020 #dumptrump #dumptrump2020 #pr...
# 1  it’s debate night, so i’ve got my earpiece and...
# 2              go joe!!! #presidentialdebate #debate
# 3  getting ready for the #debate i have rum, tequ...
# 4     who tf is still undecided? #presidentialdebate
#
#                                          punctuation  \
# 0  bidenharris2020 dumptrump dumptrump2020 presid...
# 1  its debate night so ive got my earpiece and pe...
# 2                   go joe presidentialdebate debate
# 3  getting ready for the debate i have rum tequil...
# 4       who tf is still undecided presidentialdebate
#
#                                            stopwords
# 0  bidenharris2020 dumptrump dumptrump2020 presid...
# 1  debate night ive got earpiece performance enha...
# 2                   go joe presidentialdebate debate
# 3  getting ready debate rum tequila vodka gotta r...
# 4              tf still undecided presidentialdebate

# %% [markdown]
# ### Lemmatization

# %%
#import Textblob
from textblob import TextBlob 
from textblob import Word

# %%
df1['lemmatize']=df1['stopwords'].apply(lambda x:" ".join(Word(word).lemmatize() for word in x.split()))

# %%
df1['polarity']=df1['lemmatize'].apply(lambda x: TextBlob(x).sentiment[0])## just got polarity

# %%
df1['subjectivity']=df1['lemmatize'].apply(lambda x: TextBlob(x).sentiment[1])## just got polarity

# %%
df1.head()
# Out:
#    Unnamed: 0                 date     screen_name  \
# 0         0.0  2020-09-29 23:59:39   JonDonsSweety
# 1         1.0  2020-09-29 23:59:20          Bixcut
# 2         2.0  2020-09-29 23:59:54    youngkushdro
# 3         3.0  2020-09-29 23:59:45       Divababie
# 4         4.0  2020-09-29 23:59:21  coachgratitude
#
#                                                tweet                tweet_id  \
# 0  #BidenHarris2020 #DumpTrump #DumpTrump2020 #Pr...  1.3110933115418583e+18
# 1  It’s debate night, so I’ve got my earpiece and...   1.311093234265809e+18
# 2              Go joe!!! #PresidentialDebate #debate  1.3110933766709821e+18
# 3  Getting ready for the #debate   I have rum, te...  1.3110933405118874e+18
# 4     Who TF is still undecided? #PresidentialDebate  1.3110932385232036e+18
#
#                                            lowercase  \
# 0  #bidenharris2020 #dumptrump #dumptrump2020 #pr...
# 1  it’s debate night, so i’ve got my earpiece and...
# 2              go joe!!! #presidentialdebate #debate
# 3  getting ready for the #debate i have rum, tequ...
# 4     who tf is still undecided? #presidentialdebate
#
#                                          punctuation  \
# 0  bidenharris2020 dumptrump dumptrump2020 presid...
# 1  its debate night so ive got my earpiece and pe...
# 2                   go joe presidentialdebate debate
# 3  getting ready for the debate i have rum tequil...
# 4       who tf is still undecided presidentialdebate
#
#                                            stopwords  \
# 0  bidenharris2020 dumptrump dumptrump2020 presid...
# 1  debate night ive got earpiece performance enha...
# 2                   go joe presidentialdebate debate
# 3  getting ready debate rum tequila vodka gotta r...
# 4              tf still undecided presidentialdebate
#
#                                            lemmatize  polarity  subjectivity
# 0  bidenharris2020 dumptrump dumptrump2020 presid...  0.000000      0.000000
# 1  debate night ive got earpiece performance enha...  0.200000      0.500000
# 2                   go joe presidentialdebate debate  0.000000      0.000000
# 3  getting ready debate rum tequila vodka gotta r...  0.133333      0.333333
# 4              tf still undecided presidentialdebate  0.000000      0.000000

# %% [markdown]
# ### Tweets with sentiments (-1 = negative, +1 = posiitive, 0 = neutral)

# %%
num_bins = 10
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(df1.polarity, num_bins, facecolor='green', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.title('Histogram of Tweets sentiments (-1 = negative, +1 = posiitive, 0 = neutral)')
plt.show();
